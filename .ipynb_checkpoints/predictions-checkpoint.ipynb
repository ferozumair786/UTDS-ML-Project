# %%
import pickle

# %%
import pandas as pd

# %%
walnut_model = pickle.load(open('walnut_lrcv.pkl', 'rb'))

# %%
types_df = pd.read_csv('types.csv.bz2', compression='bz2')

# %%
types_df.head()
# Out:
#    id  parent_id    scientific_name scientific_synonyms taxonomic_rank  \
# 0   1      285.0             Prunus                 NaN   Multispecies
# 1   2      843.0                NaN                 NaN            NaN
# 2   3      263.0  Citrus x sinensis                 NaN     Subspecies
# 3   4      263.0     Citrus x limon                 NaN        Species
# 4   5      263.0  Citrus x paradisi                 NaN     Subspecies
#
#              en_name en_synonyms  \
# 0               Plum         NaN
# 1  Dumpster (edible)         NaN
# 2             Orange         NaN
# 3              Lemon         NaN
# 4         Grapefruit         NaN
#
#                                en_wikipedia_url        de_name      el_name  \
# 0             http://en.wikipedia.org/wiki/Plum        Pflaume          NaN
# 1  http://en.wikipedia.org/wiki/Garbage_picking  Müllcontainer          NaN
# 2  http://en.wikipedia.org/wiki/Citrus_sinensis         Orange   Πορτοκαλιά
# 3     http://en.wikipedia.org/wiki/Citrus_limon        Zitrone      Λεμονιά
# 4  http://en.wikipedia.org/wiki/Citrus_paradisi     Grapefruit  Γκρέιπφρουτ
#
#          es_name                fr_name  he_name                    it_name  \
# 0            NaN                Prunier      NaN                     Prugno
# 1            NaN  Poubelle (comestible)      NaN  Cassonetto (commestibili)
# 2  Naranjo dulce                Oranger     תפוז              Arancio dolce
# 3          Limón             Citronnier    לימון                     Limone
# 4         Pomelo                 Pomelo  אשכולית                   Pompelmo
#
#       pl_name       pt_br_name  sv_name               category_mask  pending
# 0         NaN           Ameixa      NaN  forager, honeybee, grafter    False
# 1         NaN              NaN      NaN                     freegan    False
# 2  Pomarańcza     Laranja-doce      NaN            forager, grafter    False
# 3     Cytryna  Limão-siciliano      NaN            forager, grafter    False
# 4   Grejpfrut          Toranja      NaN            forager, grafter    False

# %%
types_df['distance_ft'] = 50

# %%
types_df.head()
# Out:
#    id  parent_id    scientific_name scientific_synonyms taxonomic_rank  \
# 0   1      285.0             Prunus                 NaN   Multispecies
# 1   2      843.0                NaN                 NaN            NaN
# 2   3      263.0  Citrus x sinensis                 NaN     Subspecies
# 3   4      263.0     Citrus x limon                 NaN        Species
# 4   5      263.0  Citrus x paradisi                 NaN     Subspecies
#
#              en_name en_synonyms  \
# 0               Plum         NaN
# 1  Dumpster (edible)         NaN
# 2             Orange         NaN
# 3              Lemon         NaN
# 4         Grapefruit         NaN
#
#                                en_wikipedia_url        de_name      el_name  \
# 0             http://en.wikipedia.org/wiki/Plum        Pflaume          NaN
# 1  http://en.wikipedia.org/wiki/Garbage_picking  Müllcontainer          NaN
# 2  http://en.wikipedia.org/wiki/Citrus_sinensis         Orange   Πορτοκαλιά
# 3     http://en.wikipedia.org/wiki/Citrus_limon        Zitrone      Λεμονιά
# 4  http://en.wikipedia.org/wiki/Citrus_paradisi     Grapefruit  Γκρέιπφρουτ
#
#          es_name                fr_name  he_name                    it_name  \
# 0            NaN                Prunier      NaN                     Prugno
# 1            NaN  Poubelle (comestible)      NaN  Cassonetto (commestibili)
# 2  Naranjo dulce                Oranger     תפוז              Arancio dolce
# 3          Limón             Citronnier    לימון                     Limone
# 4         Pomelo                 Pomelo  אשכולית                   Pompelmo
#
#       pl_name       pt_br_name  sv_name               category_mask  pending  \
# 0         NaN           Ameixa      NaN  forager, honeybee, grafter    False
# 1         NaN              NaN      NaN                     freegan    False
# 2  Pomarańcza     Laranja-doce      NaN            forager, grafter    False
# 3     Cytryna  Limão-siciliano      NaN            forager, grafter    False
# 4   Grejpfrut          Toranja      NaN            forager, grafter    False
#
#    distance_ft
# 0           50
# 1           50
# 2           50
# 3           50
# 4           50

# %%
species_df = types_df[['scientific_name', 'distance_ft']]

# %%
species_df.head()
# Out:
#      scientific_name  distance_ft
# 0             Prunus           50
# 1                NaN           50
# 2  Citrus x sinensis           50
# 3     Citrus x limon           50
# 4  Citrus x paradisi           50

# %%
species_df = species_df.dropna()

# %%
species_df = species_df.rename(columns={'scientific_name':'s_name'})

# %%
walnut_df = species_df

# %%
walnut_df[['s_name', 'distance_ft']]
# Out:
#                                           s_name  distance_ft
# 0                                         Prunus           50
# 2                              Citrus x sinensis           50
# 3                                 Citrus x limon           50
# 4                              Citrus x paradisi           50
# 5                               Persea americana           50
# 6                                     Eucalyptus           50
# 7                                         Salvia           50
# 8                         Rosmarinus officinalis           50
# 9                                  Citrus maxima           50
# 10                                     Diospyros           50
# 11                               Punica granatum           50
# 12                                  Malus pumila           50
# 13                                         Pyrus           50
# 14                                         Vitis           50
# 15                                     Lavandula           50
# 16                           Eriobotrya japonica           50
# 17                               Citrus japonica           50
# 18                                  Ficus carica           50
# 19                             Citrus reticulata           50
# 20                             Rheum rhabarbarum           50
# 21               Citrus medica var. sarcodactyli           50
# 22                                        Citrus           50
# 23                               Citrus x meyeri           50
# 24                                         Rubus           50
# 25                               Acca sellowiana           50
# 26               Brassica oleracea var. acephala           50
# 27                               Pouteria lucuma           50
# 28                                Prunus persica           50
# 29               Prunus persica var. nucipersica           50
# 30                                      Capsicum           50
# ...                                          ...          ...
# 2787                 Ficus carica 'Brown Turkey'           50
# 2788               Prunus persica 'Early Grande'           50
# 2789                       Ficus carica 'Kadota'           50
# 2790             Eriobotrya japonica 'Champagne'           50
# 2791             Eriobotrya japonica 'Bradenton'           50
# 2792             Persea americana 'Florida Hass'           50
# 2793                 Prunus persica 'Flordabest'           50
# 2794                  Diospyros kaki 'Tanenashi'           50
# 2795                Eriobotrya japonica 'Oliver'           50
# 2796                         Hericium americanum           50
# 2797                     Pyrus communis 'parker'           50
# 2798  Prunus cerasus x fruticosa 'Carmine Jewel'           50
# 2799                     Pyrus communis 'Patten'           50
# 2800                 Aronia melanocarpa 'Viking'           50
# 2801          Prunus cerasus x fruticosa 'Cupid'           50
# 2803                     Cucumis melo var. chito           50
# 2804                                       Aster           50
# 2805                        Leucanthemum vulgare           50
# 2806                          Sorghastrum nutans           50
# 2807                             Citrus jambhiri           50
# 2808                         Citrus x pyriformis           50
# 2809                     Citrus x limon 'Eureka'           50
# 2810                                  Armillaria           50
# 2811               Prunus persica 'La Feliciana'           50
# 2812                         Syzygium luehmannii           50
# 2813                     Elaeocarpus reticulatus           50
# 2814                      Prunus avium 'Rainier'           50
# 2815                            Satureja montana           50
# 2816                              Piper excelsum           50
# 2818                 Phyllostachys nigra 'Henon'           50
#
# [2747 rows x 2 columns]

# %%
walnut_df['survival'] = walnut_model.predict_proba(walnut_df[['s_name', 'distance_ft']])
walnut_df.sort_values('survival', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'survival'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1052         try:
# -> 1053             loc = self.items.get_loc(item)
#    1054         except KeyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'survival'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3458017d82de> in <module>
# ----> 1 walnut_df['survival'] = walnut_model.predict_proba(walnut_df[['s_name', 'distance_ft']])
#       2 walnut_df.sort_values('survival', ascending=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3444         self._ensure_valid_index(value)
#    3445         value = self._sanitize_column(key, value)
# -> 3446         NDFrame._set_item(self, key, value)
#    3447
#    3448         # check if we are modifying a copy
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3170
#    3171     def _set_item(self, key, value):
# -> 3172         self._data.set(key, value)
#    3173         self._clear_item_cache()
#    3174
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1054         except KeyError:
#    1055             # This item wasn't present, just insert at end
# -> 1056             self.insert(len(self.items), item, value)
#    1057             return
#    1058
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1156
#    1157         block = make_block(values=value, ndim=self.ndim,
# -> 1158                            placement=slice(loc, loc + 1))
#    1159
#    1160         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3093         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#    3097
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#      85             raise ValueError(
#      86                 'Wrong number of items passed {val}, placement implies '
# ---> 87                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#      88
#      89     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 2, placement implies 1

# %%
walnut_df['survival'] = walnut_model.predict(walnut_df[['s_name', 'distance_ft']])

walnut_df.sort_values('survival', ascending=False)
# Out:
#                            s_name  distance_ft  survival
# 992                      Prosopis           50         1
# 636                      Prosopis           50         1
# 0                          Prunus           50         0
# 1878              Spondias dulcis           50         0
# 1880               Cassia fistula           50         0
# 1881                    Nectandra           50         0
# 1882              Rosa gymnocarpa           50         0
# 1883          Vaccinium scoparium           50         0
# 1884    Cephalanthus occidentalis           50         0
# 1885                Linum lewisii           50         0
# 1886                    Digitaria           50         0
# 1887                      Populus           50         0
# 1888             Cedrela fissilis           50         0
# 1889     Physocalymma scaberrimum           50         0
# 1890          Eugenia involucrata           50         0
# 1891           Prunus campanulata           50         0
# 1892       Erythrina crista-galli           50         0
# 1893                     Cecropia           50         0
# 1894                Ocotea porosa           50         0
# 1895                Delonix regia           50         0
# 1896         Eugenia brasiliensis           50         0
# 1879           Campomanesia phaea           50         0
# 1876         Caesalpinia echinata           50         0
# 1877             Libidibia ferrea           50         0
# 1898         Patagonula americana           50         0
# 1859       Lysimachia quadrifolia           50         0
# 1860            Podocarpus elatus           50         0
# 1861       Poliomintha longiflora           50         0
# 1862                       Ananas           50         0
# 1863             Malpighia glabra           50         0
# ...                           ...          ...       ...
# 970                Yucca rupicola           50         0
# 971                  Agave weberi           50         0
# 972           Eucalyptus campaspe           50         0
# 973               Brahea calcarea           50         0
# 974                   Yucca elata           50         0
# 975               Agave americana           50         0
# 976                  Agave parryi           50         0
# 977             Agave desmettiana           50         0
# 960          Callistemon pallidus           50         0
# 958           Sambucus canadensis           50         0
# 939                   Ficus lutea           50         0
# 957                Quercus texana           50         0
# 940                       Phoenix           50         0
# 941                Arctostaphylos           50         0
# 942                      Fraxinus           50         0
# 943            Malus angustifolia           50         0
# 944          Hamamelis virginiana           50         0
# 945                  Betula lenta           50         0
# 946              Cornus nuttallii           50         0
# 947                Prunus serrula           50         0
# 948                Rhus chinensis           50         0
# 949             Salix sepulcralis           50         0
# 950                Quercus aliena           50         0
# 951      Rhododendron catawbiense           50         0
# 952           Betula occidentalis           50         0
# 953                 Carya pallida           50         0
# 954                         Sabal           50         0
# 955               Yucca aloifolia           50         0
# 956                       Quercus           50         0
# 2818  Phyllostachys nigra 'Henon'           50         0
#
# [2747 rows x 3 columns]

# %%
pecan_model = pickle.load(open('pecan_lr.pkl', 'rb'))

# %%
pecan_df = pd.read_csv('predict_df.csv')

# %%
pecan_df['survival'] = pecan_model.predict(pecan_df[['s_name', 'distance_ft']])

# %%
pecan_df['survival_chance'] = pecan_model.predict_proba(pecan_df[['s_name', 'distance_ft']])[:, 1]

# %%
pecan_df.sort_values(by='survival_chance', ascending=False)
# Out:
#      distance_ft          s_name  survival  survival_chance
# 76            45           Malus         0         0.168020
# 75            45    Coccothrinax         0         0.157660
# 33            45           Nyssa         0         0.151973
# 72            45         Syagrus         0         0.149215
# 30            45          Cornus         0         0.115215
# 65            45          Persea         0         0.111859
# 70            45        Poncirus         0         0.107587
# 28            45        Borassus         0         0.107404
# 110           45        Wisteria         0         0.100878
# 111           45       Oenothera         0         0.100878
# 94            45          Galium         0         0.100878
# 93            45           Vicia         0         0.100878
# 109           45      Helianthus         0         0.100878
# 107           45      Callicarpa         0         0.100877
# 89            45       Trifolium         0         0.100876
# 92            45        Achillea         0         0.100875
# 90            45          Ptelea         0         0.100872
# 80            45          Salvia         0         0.100839
# 113           45        Brassica         0         0.100789
# 102           45        Capparis         0         0.100600
# 2             45     Chenopodium         0         0.100473
# 101           45       Rudbeckia         0         0.100464
# 98            45         Opuntia         0         0.100459
# 112           45           Rubus         0         0.099317
# 56            45      Tamarindus         0         0.098690
# 91            45         Amorpha         0         0.098520
# 85            45  Parthenocissus         0         0.098290
# 64            45      Chamaerops         0         0.097497
# 106           45           Agave         0         0.096906
# 15            45         Solanum         0         0.096758
# ..           ...             ...       ...              ...
# 63            45    Koelreuteria         0         0.039648
# 4             45           Salix         0         0.039528
# 18            45          Cercis         0         0.039257
# 46            45    Broussonetia         0         0.039009
# 44            45       Arecaceae         0         0.038855
# 84            45      Ampelopsis         0         0.038407
# 29            45         Robinia         0         0.036834
# 87            45        Taxodium         0         0.036829
# 35            45    Washingtonia         0         0.034976
# 0             45        Sapindus         0         0.032263
# 37            45           Ulmus         0         0.031975
# 25            45           Pinus         0         0.030631
# 43            45        Triadica         0         0.029809
# 36            45       Juniperus         0         0.029107
# 48            45            Rhus         0         0.026316
# 66            45         Albizia         0         0.025404
# 41            45            Ilex         0         0.025387
# 62            45           Vitex         0         0.025371
# 22            45          Acacia         0         0.023785
# 24            45         Quercus         0         0.021870
# 7             45      Eriobotrya         0         0.021077
# 52            45          Myrica         0         0.019088
# 42            45      Podocarpus         0         0.018888
# 19            45    Umbellularia         0         0.018359
# 61            45         Arbutus         0         0.016887
# 51            45    Eysenhardtia         0         0.016041
# 21            45        Prosopis         0         0.016034
# 11            45          Punica         0         0.014932
# 16            45           Pyrus         0         0.013971
# 27            45          Brahea         0         0.012166
#
# [115 rows x 4 columns]

# %%
pecan_df[pecan_df['survival'] != 0]
# Out:
# Empty DataFrame
# Columns: [distance_ft, s_name, survival]
# Index: []

# %%
survived_df = pd.read_csv('tableau_data.csv')
survived_df.head()
# Out:
#    Unnamed: 0             s_name_x en_name_x      lon_x      lat_x  \
# 0      162564  Carya illinoinensis     Pecan -97.734367  30.288241
# 1      182851  Carya illinoinensis     Pecan -97.734881  30.289583
# 2      203141  Carya illinoinensis     Pecan -97.734438  30.278951
# 3      243715  Carya illinoinensis     Pecan -97.735491  30.291414
# 4      245971  Carya illinoinensis     Pecan -97.735491  30.291414
#
#      s_name_y       en_name_y      lon_y      lat_y  distance_ft  resistance
# 0  Morus alba  White mulberry -97.734289  30.288133    46.505648           1
# 1  Morus alba  White mulberry -97.734814  30.289648    31.792067           1
# 2  Morus alba  White mulberry -97.734328  30.278908    38.021929           1
# 3  Morus alba  White mulberry -97.735550  30.291511    40.018978           1
# 4    Borassus    Palymra palm -97.735347  30.291440    46.583791           1

# %%
survived_df[survived_df['s_name_y'].str.contains('Prosopis')]
# Out:
#       Unnamed: 0             s_name_x     en_name_x      lon_x      lat_x  \
# 61       2131283  Carya illinoinensis         Pecan -97.735311  30.283023
# 62       2151569  Carya illinoinensis         Pecan -97.735174  30.282942
# 63       2171855  Carya illinoinensis         Pecan -97.735164  30.282931
# 243      8257655  Carya illinoinensis         Pecan -97.735167  30.282980
# 710     13201956  Carya illinoinensis         Pecan -97.740608  30.295254
# 768     13526363  Carya illinoinensis         Pecan -97.759767  30.240119
# 842     14195817  Carya illinoinensis         Pecan -97.739081  30.295900
# 971     16082415  Carya illinoinensis         Pecan -97.739225  30.295847
# 1302    19875933  Carya illinoinensis         Pecan -97.710644  30.260899
# 1306    19896219  Carya illinoinensis         Pecan -97.710651  30.260956
# 1810    25454826  Carya illinoinensis         Pecan -97.759323  30.241256
# 2325    29917677  Carya illinoinensis         Pecan -97.692943  30.277482
# 2326    29917695  Carya illinoinensis         Pecan -97.692943  30.277482
